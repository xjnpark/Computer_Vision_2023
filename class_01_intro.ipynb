# %% [markdown]
# # <center>2023 Fall Semester: Computer Vision with OpenCV-Python</center>
# <h3><center>Computer Vision is a cutting edge field of Computer Science</center>
# <center>that aims to enable computers to understand what is being seen in an image</center></h3>
#
# # <center> 👉 Class_01 » _Introduction, Install_ </center>

# %% [markdown]
#  <img src='./Videos/baby.gif' align='left' width=300 height=300>

# %% [markdown]
# <img src='./Videos/DancingSo.gif' width=300 height=300>

# %% [markdown]
# # <center><u>Course Overview</u></center>
#
#
# Welcome to the Computer Vision class.
#
# This lecture is conducted in <mark><u> **_English_** </u></mark>.
# This course assumes that you are familiar with Python programming, Jupyter notebook(+ Github).
# If you do <mark><u>**_not_**</u></mark> have these prior knowledge, please choose another course.
#
# All classes are conducted in jupyter notebook.
#
# In addition, there is an <mark><u>**assignment**</u></mark> for every class, and it must be submitted as a pdf file until the day before the next class(Monday 0900).
# Grades are calculated as the sum of attendance(10%), every class assignments(60%), and a final assignment(30%).
#
# I hope you have a fun and rewarding semester.
#
# Park, Jang Kyoung
#
# e-mail: xjnpark@hanmail.net, xjnpark@ssu.ac.kr,  **use LMS Inbox (메시지함)**
# github: [xjnpark](https://github.com/xjnpark/Computer_Vision_2023)
# kakao talk & cp: 010-9970-5149

# %% [markdown]
# # ▣ Introduction
# ## ▶ Image Processing and Computer Vision
# https://www.mygreatlearning.com/blog/opencv-tutorial-in-python
#
# **Image processing** and **Computer Vision** both are very exciting field of Computer Science.
#
# * A computer vision system uses the image processing algorithms to try and perform emulation of vision at human scale.
# >- For example, if the goal is to enhance the image for later use, then this may be called **image processing.**
# >- And if the goal is to recognise objects, defect for automatic driving, then it can be called **computer vision.**
#
# * Image Processing is the field of enhancing the images by tuning many parameter and features of the images.
# - So Image Processing is the subset of Computer Vision.
# >- Transformations are applied to an input image and the resultant output image is returned.
# >- Some of these transformations are- sharpening, smoothing, stretching etc.
#
#
# * In Computer Vision, computers or machines are made to gain high-level understanding from the input digital images or videos with the purpose of automating tasks that the human visual system can do.
# >- It uses many techniques and Image Processing is just one of them.
#
# * **Image processing** is the process of obtaining a new desired result by applying various operations to an image.
# >- The goal of most image processing is to obtain better quality images.
# >- Examples of image processing include image **quality improvement, image restoration, and image segmentation.**
#
# * **Computer vision** is a comprehensive concept that includes image processing.
# >- If image processing is a technology that transforms an original image into a new image desired by the user,
# >- computer vision is a technology that extracts meaningful information from an image.
# >- For example, **Object Detection, Object Tracking, and Object Recognition.**
# >>- **Object detection** is the task of detecting where the object you are looking for is located in the image,
# >>- **object tracking** is the task of tracking where the object is moving in the image, and
# >>- **object recognition** is the task of recognizing the object in the image.
# >>>- Object tracking is familiar, but object detection and object recognition can be confused with each other.
# >>>- You can think of **object recognition** as the task of showing a picture of a dog and determining _whether it is a dog or a cat_.
# >>>- **Object detection**, on the other hand, can be thought of as showing a picture of several dogs and cats and figuring out _where the dog is_.
# >>>
# >>>※ While **object recognition** only needs to distinguish whether it is a dog or a cat,
# >>>**object detection** is a more difficult task because the location of the dog must be located within the image.
#
# In general, **_image processing is often done before computer vision_**.
# This is because computer vision work is the process of converting an original image into a new desired image through image processing and then obtaining the desired information through computer vision.
#
# ### - Difference between Image Processing and Computer Vision:
#
# |<center>Image Processing</center>|<center>Computer Vision</center>|
# |----------------------|------------------|
# |<center>Image processing is mainly focused on processing the raw input images to enhance them or preparing them to do other tasks</center>|<center>Computer vision is focused on extracting information from the input images or videos to have a proper understanding of them to predict the visual input like human brain.</center>|
# |<center>Image processing uses methods like Anisotropic diffusion, Hidden Markov models, Independent component analysis, Different Filtering etc.</center>|<center>Image processing is one of the methods that is used for computer vision along with other Machine learning techniques, CNN etc.</center>
# |<center>Image Processing is a subset of Computer Vision.</center>|<center>Computer Vision is a superset of Image Processing.</center>
# |<center>Examples of some Image Processing applications are- Rescaling image (Digital Zoom), Correcting illumination, Changing tones etc.</center>|<center>Examples of some Computer Vision applications are- Object detection, Face detection, Hand writing recognition etc.</center>
#
# https://www.geeksforgeeks.org/difference-between-image-processing-and-computer-vision/
#
#
# <img src='./images/ip_cv.png ' width=400 height=400>
#
# <img src='./images/cv_ip.png' align='left' width=300 height=300> <img src='./images/cv_ip2.png'  width=400 height=800>
#
#
# <img src = './images/tesla-driverless.gif' width=900 height=400>
# Tesla’s driverless system detecting objects in a foggy scenario via [Source](https://assets.bwbx.io/images/users/iqjWHBFdfxIU/i7FdQDTJdEAo/v0/-999x-999.gif)

# %% [markdown]
# ## OpenCV
#
# Gary Bradsky invented OpenCV in 1999 and officially launched in 1999, OpenCV (Open Source Computer Vision) from an Intel initiatives.
#
# - Vadim Pisarevsky joined Gary Bradsky to manage Intel’s Russian software OpenCV team.
# - In 2005, OpenCV was used on Stanley, the vehicle who won 2005 DARPA Grand Challenge.
# - Later its active development continued under the support of Willow Garage, with Gary Bradsky and Vadim Pisarevsky leading the project.
# - Right now, OpenCV supports a lot of algorithms related to Computer Vision and Machine Learning and it is expanding day-by-day.
#
# Currently OpenCV supports a wide variety of programming languages like C++, Python, Java etc and is available on different platforms including Windows, Linux, OS X, Android, iOS etc.
# Also, interfaces based on CUDA and OpenCL are also under active development for high-speed GPU operations.
#
# OpenCV-Python is the Python API of OpenCV. It combines the best qualities of OpenCV C++ API and Python language.
#
# ## OpenCV-Python
#
# OpenCV is an open-source software library for computer vision and machine learning.
# - The OpenCV full form is Open Source Computer Vision Library.
# - It was created to provide a shared infrastructure for applications for computer vision and to speed up the use of machine perception in consumer products.
#
#
# This library is based on optimised C / C++ and supports Java and Python along with C++ through an interface.
# The library has more than 2500 optimised algorithms, including an extensive collection of computer vision and machine learning algorithms, both classic and state-of-the-art.
#
# - First major release 1.0 was in 2006, second in 2009 and third in 2015.
# - OpenCV 2.4.13 is latest stable release for OpenCV 2.X.
# - Open 3.X is very similar, and has some benefits and new functions, however, it also removed some of the important algorithms (due to patents) such as SIFT & SURF.
# - OpenCV 4.7.0 is the latest version for OpenCV
#
# Using OpenCV it becomes easy to do complex tasks such as identify and recognise faces, identify objects, classify human actions in videos, track camera movements, track moving objects, extract 3D object models, generate 3D point clouds from stereo cameras, stitch images together to generate an entire scene with a high resolution image and many more.
#
# Python is a user friendly language and easy to work with but this advantage comes with a cost of speed, as Python is slower to languages such as C or C++.
# So they extend Python with C/C++, which allows us to write computationally intensive code in C/C++ and create Python wrappers that can be used as Python modules.
# Doing this, the code is fast, as it is written in original C/C++ code (since it is the actual C++ code working in the background) and also,
# it is easier to code in Python than C/C++.
# **OpenCV-Python is a Python wrapper for the original OpenCV C++ implementation.**
#
# ### &#x1F600;  Visit - [opencv.org](https://docs.opencv.org/4.7.0/d1/dfb/intro.html) or [wikipedia](https://en.wikipedia.org/wiki/OpenCV) to learn more
#
# <img src = './images/OpenCV-python-logo.png' width=600 height=200>

# %% [markdown]
# ## ▶  What is an image?
#
# An image is defined as a two-dimensional function,F(x,y).
# Images are represented in rows and columns in which images are represented:
#
# <img src='./images/img_mat.png' width=400 height=200>
#
# - where x and y are spatial coordinates,
# - and the amplitude of F at any pair of coordinates (x,y) is called the intensity of that image at that point.
# - When x,y, and amplitude values of F are finite, we call it a **_digital image_**.
# - In other words, an image can be defined by a two-dimensional array specifically arranged in rows and columns.
# - These elements are referred to as picture elements,image elements,and pixels.
# - A **Pixel** is most widely used to denote the elements of a Digital Image.
#
# ### ● Digital image :
# - is an image composed of picture elements, also known as pixels, each with finite, discrete quantities of numeric representation for its intensity or grey level.
# - So the computer sees an image as numerical values of these pixels and in order to recognise a certain image, it has to recognise the patterns and regularities in this numerical data.
# - There are two types of digital image : color & grayscale.
#
# <img src='./images/practice_img/digital2.png' width=400 height=200>
#
# * Grayscale Image
# >- The pixel value of the grayscale image represents the brightness of the pixel.
# >- The value 0 is black, the value 255 is white, and the values in between makeup different shades of gray.
# >- The darker pixels are represented by a number closer to the zero and lighter pixels are represented by numbers approaching one.
#
# <img src = './images/practice_img/gradient.png' align='center' width=150 height=100> <img src = './images/Pixel.png' width=400 height=250>
#
#
#
# * Color Image :
# >- But usually, you will find that for any colour image, there are 3 primary channels – Red, green and blue and the value of each channel varies from 0-255.
# >- In more simpler terms we can say that a digital image is actually formed by the combination of three basic colour channels  Red, green, and blue
# >- whereas for a grayscale image we have only one channel whose values also vary from 0-255.

# %% [markdown]
# ## ▶  Img Channels
#
# ### ■ RGB Channel
#
# <img src = './images/rgb-2.png' width=300 height=200>

# %% [markdown]
# ### ■ Standard is RGB,
#
# * [Amount of Red, Green, Blue], 0(none) ~ 255(all)
# >- [0,0,0]:Black,
# >- [255,0,0]:Red,
# >- [0,255,0]:Green,
# >- [0,0,255]:Blue,
# >- [255,255,255]:White,
# >- [255,255,0] : Yellow,
# >- [0,255,255] : Light Blue, etc
#
# ### ■ OpenCV uses BGR
# * [Amount of Blue, Green, Red], 0(none) ~ 255(all)
# >- [0,0,0]  :Black,
# >- [255,0,0]:Blue,
# >- [0,255,0]:Green,
# >- [0,0,255]:Red,
# >- [255,255,255]:White,
# >- [0,255,255]  :Yellow, etc

# %%
from PIL import Image
rgb = Image.open("./images/rgb_circle.png")
bgr = Image.open("./images/bgr.png")

plt.figure(figsize=(7,7))
plt.subplot(1,2,1),plt.imshow(rgb),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(bgr),plt.axis('off')
# plt.subplot(1,3,3),plt.imshow(travel),plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# By default, the imread function reads images in the BGR (Blue-Green-Red) format.
# We can read images in different formats using extra flags in the imread function:
#
# - cv2.IMREAD_COLOR: Default flag for loading a color image
# - cv2.IMREAD_GRAYSCALE: Loads images in grayscale format
# - cv2.IMREAD_UNCHANGED: Loads images in their given format, including the alpha channel. Alpha channel stores the transparency information – the higher the value of alpha channel, the more opaque is the pixel
#
# ### ■ BGR to RGB
#
# A color space is a protocol for representing colors in a way that makes them easily reproducible.
# We know that grayscale images have single pixel values and color images contain 3 values for each pixel – the intensities of the Red, Green and Blue channels.
# Most computer vision use cases process images in **RGB** format.
# However, applications like video compression and device independent storage – these are heavily dependent on other color spaces, like the Hue-Saturation-Value or HSV color space.
# As you understand a RGB image consists of the color intensity of different color channels, i.e. the intensity and color information are mixed in RGB color space but in HSV color space the color and intensity information are separated from each other.
# This makes HSV color space more robust to lighting changes.
#
# OpenCV reads a given image in the **BGR** format by default.
# So, you'll need to change the color space of your image from BGR to RGB when reading images using OpenCV.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('./images/ex01.jpg', cv2.IMREAD_COLOR) # read BGR
img2 = plt.imread('./images/ex01.jpg', cv2.IMREAD_COLOR) # read RGB
img.shape, img2.shape
# Out:
# ((682, 1024, 3), (682, 1024, 3))

# %%
cv2.imshow('OpenCV read BGR image',img) # expects true color
cv2.imshow('Plt read RGB image',img2) # expects distorted color
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from matplotlib.pyplot import figure
figure(figsize=(15, 15), dpi=100)

plt.subplot(131),plt.imshow(img),plt.title('OpenCV read image matPlot'),plt.axis('off')
plt.subplot(132),plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)),plt.title('cvt.BGR2RGB_matplt image'),plt.axis('off')
plt.subplot(133),plt.imshow(img2),plt.title('matplt read image'),plt.axis('off')

plt.show()

# %% [markdown]
# ## ▶ Types of an image
#
# - **BINARY IMAGE** – The binary image as its name suggests, contain **only two pixel elements i.e 0 & 1,where 0 refers to black and 1 refers to white.** This image is also known as Monochrome.
# - **BLACK AND WHITE IMAGE** – The image which consist of **only black and white color(0 to 255)** is called BLACK AND WHITE IMAGE. The pixel value of the grayscale image represents the brightness of the pixel. The value **0 is black, the value 255 is white**, and the values in between makeup different shades of gray.
#
# - **8 bit COLOR FORMAT** – It is the most famous image format. It has 256 different shades of colors in it and commonly known as Grayscale Image. In this format, **0 stands for Black, and 255 stands for white, and 127 stands for gray.**
# - **16 bit COLOR FORMAT** – It is a color image format. It has 65,536 different colors in it. It is also known as High Color Format. In this format the distribution of color is not as same as Grayscale image. A 16 bit format is actually divided into three further formats which are Red, Green and Blue. That famous RGB format.
#
# ➡️ [Compression Type : JPG, JPEG, PNG, WebP and more](https://kinsta.com/blog/image-file-types/)
# - https://themeisle.com/blog/best-image-format/#gref ,
# - https://guides.lib.umich.edu/c.php?g=282942&p=1885348
# - Because of their different compression processes, JPEGs contain less data than PNGs — and therefore, are usually smaller in size. Unlike JPEGs, PNGs support transparent backgrounds, making them preferred for graphic design.

# %%
import cv2
import matplotlib.pyplot as plt
import pandas as pd

img_bi = cv2.imread('./images/bi_img.png',0)
img_gray = cv2.imread('./images/Gray_scaled.jpg',0)
img_col = cv2.imread('./images/8vs16bit.png',-1)

# fig.set_figwidth(20) fig.set_figheight(10) aspect='0.8'

fig, axs = plt.subplots(1,3,figsize=(10,10))
axs[0].imshow(img_bi, cmap='gray'), axs[0].axis('off'), axs[0].set_title('BINARY IMAGE')
axs[1].imshow(img_gray,cmap='gray'), axs[1].axis('off'), axs[1].set_title('BLACK_WHITE(Gray_scaled)')
axs[2].imshow(img_col, fig.set_figwidth(25), aspect='1.5'), axs[2].axis('off'), axs[2].set_title('8 vs 16 bit')
plt.show()

# %% [markdown]
# ### ■ Image is nothing but an Numpy array

# %%
# make color img
from PIL import Image
import numpy as np

w, h = 64, 32
img_src = np.zeros((h, w, 3), dtype=np.uint8) # 0 ; black, 255: white

# img = Image.fromarray(img_src, 'RGB')
img_src += 150
# img_src
img = Image.fromarray(img_src, 'RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x32 at 0x21477CAB9E8>

# %%
for row in range(32):
    for col in range(64):
        img_src[row,col] = [255,255,0] # yellow
        
img = Image.fromarray(img_src, 'RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x32 at 0x21477CAB8D0>

# %%
img_enl = img.resize((200, 100))
img_enl
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x214731E8EB8>

# %%
# make color img
from PIL import Image
import numpy as np

w, h = 64, 64
img_src = np.zeros((h, w, 3), dtype=np.uint8) # 0 ; black, 255: white

for row in range(32):
    for col in range(32):
        img_src[row,col] = [255,255,0] # yellow

for row in range(32):
    for col in range(32):
        img_src[row+32,col] = [255,0,0] # red     
        
for row in range(32):
    for col in range(32):
        img_src[row,col+32] = [0,0,255] # blue

for row in range(32):
    for col in range(32):
        img_src[row+32,col+32] = [0, 255,0] # green     
        
img = Image.fromarray(img_src, 'RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x195FD720358>

# %%
img_np = np.array(img)
img_np[0:32,0:32,:]
# Out:
# array([[[255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0],
#         ...,
#         [255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0]],
#
#        [[255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0],
#         ...,
#         [255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0]],
#
#        [[255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0],
#         ...,
#         [255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0]],
#
#        ...,
#
#        [[255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0],
#         ...,
#         [255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0]],
#
#        [[255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0],
#         ...,
#         [255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0]],
#
#        [[255, 255,   0],
#         [255, 255,   0],
#         [255, 255,   0],
# ...

# %% [markdown]
# ## ▶  Why use black and white images?
# 1. **Using a monochrome image helps in reducing the complexity of computations which involve image processing.**
# 2. Enhances easy visualization as it converts an image having three dimensions (R, G, and B) to a 2 dimensional one highlighting the shadows and the bright portions of a picture.
# 3. It makes image recognition easier.
# 4. Converting a RGB image to monochrome compresses an image to it’s bare minimum size which is useful.
# 5. It helps in improving the speed of a program by cutting it’s processing time by a factor of three or maybe sometimes even four.
# 6. To reduce the pixel data which might take up additional and unnecessary space during processing.

# %%
img_plt = plt.imread('./images/dogs/04.jpg', 1) 
img_gray = cv2.cvtColor(img_plt, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
plt.imshow(img_plt) 
plt.show()

# %%
img_plt.max()
# Out:
# 255

# %%
# Pandas
pd.Series(img_plt.flatten()).plot(kind='hist', bins=50, title='Dist of Pxl Value' )
plt.show()

# %%
# Matplotlib
plt.hist(img_plt.ravel(),256,[0,256])
plt.show()

# %%
# OpenCV-Python
hist = cv2.calcHist([img_plt], [0], None, [256], [0,256])
plt.plot(hist),plt.title('Hist_cv2')
# Out:
# ([<matplotlib.lines.Line2D at 0x214784f1748>], Text(0.5, 1.0, 'Hist_cv2'))

# %% [markdown]
# ## ▶ Install OpenCV-contrib-Python in Windows
# There are many ways in which you can install OpenCV on your computer. Here are some:
#
# ### ■ Install Anaconda
# Miniconda is the minimal set of features from the very large Anaconda Python distribution.  Download Miniconda from the following URL:
# - [Miniconda](https://docs.conda.io/en/latest/miniconda.html)
#
# Once Miniconda has been downloaded you must create a Python 3.x environment. So you must execute the following commands:
#
# > **conda create -y --name _CV2023Fall_ python=3.6**
#
# * _CV2023Fall_ can be changed to your name
#
# To enter this environment, you must use the following command (**for Windows**), this command must be done every time you open a new Anaconda/Miniconda terminal window:
#
# > **_activate _CV2023Fall__**
#
# ### • Install opencv-contrib-python using Anaconda for Windows
#
# The opencv-contrib-python repository contains both the main modules along with the contrib modules
# opencv-python:  https://github.com/opencv/opencv_contrib
# - opencv-contrib-python storage is a repository that contains code that is not yet mature in its algorithm
# - The code in the contrib repository will be moved to the main repository as it matures in the future.
#
# - Main modules of the OpenCV library : https://github.com/opencv/opencv
#
# > **conda install -c michael_wild opencv-contrib**
#
# >- _pip install opencv-contrib-python_ : not recomended
# >- _conda install -c conda-forge opencv_, pip install opencv-python : for opencv-python
#
# > **Don't install both opencv-python, and opencv-contrib-python,**
# > only the latter (else the former will "shadow" it, and you cannot use contrib modules.
# > this is the reason for AttributeError: module 'cv2.cv2' has no attribute 'xfeatures2d')
#
# ### ■ Install Jupyter Notebook
#
# it is easy to install Jupyter notebooks with the following command:
#
# > **_conda install -y jupyter_**
#
# Once Jupyter is installed, it is started with the following command:
#
# > **_jupyter notebook_**
#
# The following packages are needed for this course:
#
# >conda install -y scipy
# pip install --exists-action i --upgrade scikit-learn
# conda install -c anaconda pandas
# pip install --exists-action i --upgrade pandas-datareader
# pip install --exists-action i --upgrade matplotlib
# pip install --exists-action i --upgrade pillow
# pip install --exists-action i --upgrade tqdm
# pip install --exists-action i --upgrade requests
# pip install --exists-action i --upgrade h5py
# pip install --exists-action i --upgrade pyyaml
# pip install --exists-action i --upgrade gensim
# conda install -c conda-forge dlib
# pip install --exists-action i --upgrade gym
# pip install --exists-action i --upgrade xlrd
# pip install --exists-action i --upgrade folium
# conda update -y --all
# conda update -n base -c defaults conda
#
#
# You should also link your new CV environment to Jupyter so that you can choose it as a Kernal.
# Always make sure to run your Jupyter notebooks from your 3.6 kernel.
#
# > **_python -m ipykernel install --user --name CV2023Fall --display-name "CV-py36_"**

# %% [markdown]
# ### ■ dlib Install
# https://pypi.org/project/dlib/
#
# When you have issues on dlib installation, follows next steps:
# 1. Install CMAKE
# >- **pip install cmake**
#
# 2. dlib download
# >- **conda install -c conda-forge dlib**  or
# >- **pip install dlib**
#
# 3. Install Visual Studio 2022
#
# https://suy379.tistory.com/76
# https://pyimagesearch.com/2021/04/19/face-detection-with-dlib-hog-and-cnn/

# %% [markdown]
# ### ■ Check OpenCV-Python and other packages

# %%
import numpy
import cv2
import matplotlib
import dlib

print('numpy = ',numpy.__version__)
print('cv2 = ',cv2.__version__)
print('matplotlib = ',matplotlib.__version__)
print('dlib = ',dlib.__version__)
# Out:
# numpy =  1.19.5
# cv2 =  3.3.1
# matplotlib =  3.3.4
# dlib =  19.22.0

# %% [markdown]
# # Main References :
# [OpenCV-Python Tutorials](https://opencv24-python-tutorials.readthedocs.io/en/latest/py_tutorials/py_tutorials.html)
# <img src='./images/OpenCV-python-tutorial.png' width=200 height=400>

# %% [markdown]
# # OpenCV-Python Tutorials - Contents
#
# ## 1. Introduction to OpenCV
# >1.1 Introduction to OpenCV-Python Tutorials
# >1.2 Install OpenCV-Python in Windows
# # 2. Gui Features in OpenCV
# >2.1 Getting Started with Images
# >2.2 Getting Started with Videos
# >2.3 Drawing Functions in OpenCV
# >2.4 Mouse as a Paint-Brush
# >2.5 Trackbar as the Color Palette
# # 3. Core Operations
# >3.1 Basic Operations on Images
# >3.2 Arithmetic Operations on Images
# >3.3 Performance Measurement and Improvement Techniques
# # 4. Image Processing in OpenCV
# > 4.1 Changing Colorspaces
# > 4.2 Geometric Transformations of Images
# > 4.3 Image Thresholding
# > 4.4  Smoothing Images
# > 4.5  Morphological Transformations
# > 4.6  Image Gradients
# > 4.7  Canny Edge Detection
# > 4.8  Image Pyramids
# > 4.9  Contours in OpenCV
# > 4.10  Histograms in OpenCV
# > 4.11 Image Transforms in OpenCV
# > 4.12  Template Matching
# > 4.13  Hough Line Transform
# > 4.14  Hough Circle Transform
# > 4.15  Image Segmentation with Watershed Algorithm
# > 4.16  Interactive Foreground Extraction using GrabCut Algorithm
# # 5. Feature Detection and Description
# >5.1 Understanding Features
# >5.2 Harris Corner Detection
# >5.3 Shi-Tomasi Corner Detector & Good Features to Track
# >5.4 Introduction to SIFT (Scale-Invariant Feature Transform)
# >5.5 Introduction to SURF (Speeded-Up Robust Features)
# >5.6 FAST Algorithm for Corner Detection
# >5.7 ORB (Oriented FAST and Rotated BRIEF)
# >5.8 Feature Matching
# >5.9 Feature Matching + Homography to find Objects
# # 6. Video Analysis
# >6.1 Meanshift and Camshift
# >6.2 Optical Flow
# >6.3 Background Subtraction
#
# # 7. Camera Calibration and 3D Reconstruction
# >7.1 Camera Calibration
# >7.2 Pose Estimation
# >7.3 Epipolar Geometry
# >7.4 Depth Map from Stereo Images : Extract depth information from 2D images.
# # 8. Machine Learning
# >8.1 K-Nearest Neighbour
# >8.2 Support Vector Machines (SVM)
# >8.3 K-Means Clustering
# # 9. Computational Photography
# >9.1 Image Denoising
# >9.2 Image Inpainting
# # 10. Object Detection
# >10.1 Face Detection using Haar Cascades
#
# [OpenCV - Github](https://github.com/opencv)

# %% [markdown]
# # <center>GK-OpenCV Python Tutorial - Index</center>
# <center>https://www.geeksforgeeks.org/opencv-python-tutorial </center>
#
# ## 1. Getting Started
# > - 1.1 Install OpenCV for Python on Windows
# > - 1.2 Introduction to OpenCV
# >> - Reading an image
# >> - Extracting the RGB values of a pixel
# >> - Extracting the Region of Interest (ROI)
# >> - Resizing the Image
# >> - Rotating the Image
# >> - Drawing a Rectangle
# >> - Displaying text
# ## 2. Working with Images
# >### 2.1 Basic Operation
# >> - 2.1.1 Reading/Display/Writing/Saving an image in OpenCV using Python
# >> - 2.1.2 Color Spaces
# >> - 2.1.3 Arithmetic operations on Images
# >> - 2.1.4 Bitwise Operations on Binary Images
# >> - 2.1.5 Draw a line/circle/rectangle/ellipse/text string
# >> - 2.1.6 Find and Draw Contours
# >> - 2.1.7 Draw a triangle with centroid
# >### 2.2 Image Processing
# >> - 2.2.1 Image Resizing
# >> - 2.2.2 Eroding/Blurring an Image
# >> - 2.2.3 Create Border around Images
# >> - 2.2.4 Grayscaling of Images
# >> - 2.2.5 Scaling, Rotating, Shifting and Edge Detection
# >> - 2.2.6 Erosion and Dilation of images
# >> - 2.2.7 Analyze an image using Histogram
# >>> - Histograms Equalization
# >>> - Simple Thresholding
# >>> - Adaptive Thresholding
# >>> - Otsu Thresholding
# >>> - Segmentation using Thresholding
# >> - 2.2.8 Convert an image from one color space to another
# >> - 2.2.9 Filter Color with OpenCV
# >> - 2.2.10 Denoising of colored images
# >> - 2.2.11 Visualizing image in different color spaces
# >> - 2.2.12 Find Co-ordinates of Contours
# >> - 2.2.13 Bilateral Filtering
# >> - 2.2.14 Image Inpainting using OpenCV
# >> - 2.2.15 Intensity Transformation Operations on Images
# >> - 2.2.16 Image Registration
# >> - 2.2.17 Background subtraction
# >>> - Background Subtraction in an Image using Concept of Running Average
# >>> - Foreground Extraction in an Image using Grabcut Algorithm
# >> - 2.2.18 Morphological Operations in Image Processing :Opening/Closing/Gradient
# >>> - Image segmentation using Morphological operations
# >> - 2.2.19 Image Translation
# >> - 2.2.20 Image Pyramid
# >### 2.3 Feature Detection and Description
# >> - 2.3.1 Line detection using Houghline method
# >> - 2.3.2 Circle Detection
# >> - 2.3.3 Detect corner of an image
# >>> - Corner Detection with Shi-Tomasi method
# >>> - Corner detection with Harris Corner Detection
# >> - 2.3.4 Find Circles and Ellipses in an Image
# >> - 2.3.5 Document field detection
# >> - 2.3.6 Smile detection
# ## 3. Working with Videos
# > - 3.1 Play a video using OpenCV
# > - 3.2 Create video using multiple images
# > - 3.3 Extract images from video
# ## 4. Applications and Projects
# > - 4.1 Extract frames using OpenCV
# > - 4.2 Displaying the coordinates of the points clicked on the image using Python-OpenCV
# > - 4.3 White and black dot detection
# > - 4.4 OpenCV BGR color palette with trackbars
# > - 4.5 Draw rectangular shape and extract objects
# > - 4.6 Invisible Cloak using OpenCV
# > - 4.7 Unsupervised Face Clustering Pipeline
# > - 4.8 Saving Operated Video from a webcam
# > - 4.9 Face Detection using Python and OpenCV with webcam
# > - 4.10 Opening multiple color windows
# > - 4.11 Play a video in reverse mode
# > - 4.12 Template matching using OpenCV in Python
# > - 4.13 Cartooning an Image using OpenCV – Python
# > - 4.14 Vehicle detection in a Video frame using Python – OpenCV
# > - 4.15 Count number of Faces using Python – OpenCV
# > - 4.16 Live Webcam Drawing using OpenCV
# > - 4.17 Detect and Recognize Car License Plate from a video in real time

# %% [markdown]
# ## ▣ Course References :
# - [OpenCV-Python Tutorials](https://opencv24-python-tutorials.readthedocs.io/en/latest/py_tutorials/py_tutorials.html) : Official OpenCV-Python Tutorials
# - [Getting Started with OpenCV](https://learnopencv.com/getting-started-with-opencv/) : LearnOpenCV for Beginners
# - [Introduction to OpenCV](https://www.geeksforgeeks.org/introduction-to-opencv/)
# - [OpenCV Tutorial: A Guide to Learn OpenCV in Python](https://www.mygreatlearning.com/blog/opencv-tutorial-in-python/)
# - [OpenCV: Open Source Computer Vision Library](https://github.com/opencv/opencv/tree/4.x)
# - [opencv-python](https://github.com/opencv/opencv-python)
# - [opencv](https://github.com/opencv/opencv/tree/4.x/data)
# - [opencv-course](https://github.com/jasmcaus/opencv-course/tree/master)
# - [Master-Computer-Vision-OpenCV3-in-Python-and-Machine-Learning](https://github.com/PacktPublishing/Master-Computer-Vision-OpenCV3-in-Python-and-Machine-Learning/tree/master)
# - [OpenCV Course](https://www.youtube.com/watch?v=oXlwWbU8l2o)
# - [Image Processing with OpenCV and Python](https://www.youtube.com/watch?v=kSqxn6zGE0c)
# - [OpenCV Python Tutorial](https://www.youtube.com/watch?v=qCR2Weh64h4&list=PLzMcBGfZo4-lUA8uGjeXhBUUzPYc6vZRn&index=1)
# - [귀퉁이 서재](https://bkshin.tistory.com/entry/OpenCV-4/)
# - [파이썬으로 만드는 OpenCV 프로젝트-github](https://github.com/BaekKyunShin/OpenCV_Project_Python/tree/master/)
# - [파이썬으로 만드는 OpenCV 프로젝트], 이세우, 인사이트(insight), 2019.
# - [OPENCV로 배우는 영상처리 및 응용], 정성환.배종욱, 생능출판사, 2018.
# - [컴퓨터그래픽스],김성호, 생능출판사, 2013.
# - [OpenCV Computer Vision with Python], Joseph Howse, BIRMINGHAM - MUMBAI, 2013.
# - [OpenCV with Python Blueprints], Michael Beyeler, BIRMINGHAM - MUMBAI, 2015.
# - [The OpenCV Tutorials] - Release 2.4.13.5, February 05, 2018
# - [Practical Python and OpenCV:An Introductory,Example Driven Guide to Image Processing and Computer Vision], 3rd Edition, Dr.Adrian Rosebrock, pyimagesearch, 2016.
# - https://bkshin.tistory.com/entry/OpenCV-4/
# - https://github.com/BaekKyunShin/OpenCV_Project_Python/tree/master/02.interface
#
# ## ▣ Resources
#
# - Images : [OpenCV - Github](https://github.com/opencv), and more
# - VideoSources : All videos used in this post are in the public domain, and more
# >- [261+ Free Walking People 4K & HD Stock Videos](https://pixabay.com/videos/search/walking%20people/)
# >- [Free Walking Videos](https://www.pexels.com/search/videos/walking/)
# >- [Free Traffic Videos](https://www.pexels.com/search/videos/traffic/)
# >- [Charlie Chaplin](https://www.pond5.com/stock-footage/item/44516099-charlie-chaplin-kid-auto-races-venice-1914#1)
# >- [Race Car](https://pixabay.com/videos/car-racing-motor-sports-action-74/)
# >- [Street Scene](https://pixabay.com/videos/street-walk-urban-city-walking-5025/).

# %% [markdown]
# # Jupyter Notebook File Titles using in Class
# 'class_01_1_intro.ipynb',
# 'class_02_1_IP_Img_basic_op.ipynb',
# 'class_02_2_IP_ROI_PxlAccess.ipynb',
# 'class_02_3_IP_Color_Spaces.ipynb',
# 'class_02_4_IP_Color_Map.ipynb',
# 'class_02_5_IP_Color_Spaces.ipynb',
# 'class_03_1_IP_arithmatic.ipynb',
# 'class_03_2_IP_trans_rotat.ipynb',
# 'class_04_1_draw_function_all.ipynb',
# 'class_05_1_event_key_mouse_all.ipynb',
# 'class_05_2_window_control_trbar.ipynb',
# 'class_06_1_IP_affin_trans.ipynb',
# 'class_06_2_IP_binary_threshold.ipynb',
# 'class_06_3_IP_smoothing(blurring).ipynb',
# 'class_06_4_IP_grad_edge.ipynb',
# 'class_07_1_IP_contours_moment.ipynb',
# 'class_07_2_IP_remapping.ipynb',
# 'class_08_1_IP_Histo_Norm_Eqlz_CLAHE.ipynb',
# 'class_08_2_IP_2D_Histo.ipynb',
# 'class_08_3_IP_Histogram_Img.ipynb',
# 'class_08_4_IP_HOG.ipynb',
# 'class_09_1_Lens_Distortion.ipynb',
# 'class_10_1_IP_Blob_detection.ipynb',
# 'class_11_1_IP_morphology_transform.ipynb',
# 'class_11_2_IP_Dist_Transformation.ipynb',
# 'class_12_1_img_blending.ipynb',
# 'class_12_2_img_denoising.ipynb',
# 'class_12_3_IP_inpainting.ipynb',
# 'class_13_1_feature_matching_corr.ipynb',
# 'class_13_2_img_pyramid_blending.ipynb',
# 'class_13_3_Template_matching.ipynb',
# 'class_13_4_IP_Img_Matching.ipynb',
# 'class_13_5_IP_Feature_Matching.ipynb',
# 'class_14_1_Hough_detect_Transformation.ipynb',
# 'class_14_2_IP_Feature_Understand.ipynb',
# 'class_14_3_IP_corner_convex.ipynb',
# 'class_14_4_keypoints_detect.ipynb',
# 'class_14_5_find_circle_ellips.ipynb',
# 'class_14_6_SIFT_SURF_ORB.ipynb',
# 'class_14_7_IP_smile_detection.ipynb',
# 'class_15_1_video_read.ipynb',
# 'class_15_2_video_basic_op.ipynb',
# 'class_15_3_video_bgsubtract.ipynb',
# 'class_15_4_video_match_track.ipynb',
# 'class_15_5_video_obj_track.ipynb',
# 'class_15_6_video_obj_det_HOG.ipynb',
# 'class_15_7_video_mean_shift_obj_track.ipynb',
# 'class_15_8_video_cap_rec.ipynb',
# 'class_17_1_CV_Haar-Face Detection.ipynb',
# 'class_17_2_CV_HOG-Face Detection.ipynb',
# 'class_17_3_CV_LBPH.ipynb',
# 'class_17_4_CV_pose_estimation.ipynb',
# 'class_18_1_DL_Computer_Vision.ipynb',
# 'class_18_2_DL_Face_Recognition.ipynb  ',
# 'class_18_3_DL_emotion_clasfy.ipynb',
# 'class_18_4_DL_Kmean_Color_Quantization.ipynb'

# %% [markdown]
# ## Assgn 01
#
# * Run the below code and save as a pdf file including output
# * file name = 'your_name_assgn01.pdf'
# * Upload to LMS before the next Monday 0900(It's checked by LMS program automatically, so you must upload before the date)

# %%
import numpy
import cv2
import matplotlib
import dlib

print('numpy = ',numpy.__version__)
print('cv2 = ',cv2.__version__)
print('matplotlib = ',matplotlib.__version__)
print('dlib = ',dlib.__version__)
